# %% [markdown]
# # **PROYECTO SCHUTZ EN PYTHON PARA CREACIÓN DE DASHBOARD 2 - PARTE 1**

# %% [markdown]
# ## 1.- IMPORTACIÓN DE LIBRERÍAS PARA EL PROYECTO

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from io import StringIO
from itertools import zip_longest
import io
import requests
from io import BytesIO
import pandas as pd
import chardet
import re
from oauth2client.service_account import ServiceAccountCredentials
import gspread
from gspread_dataframe import set_with_dataframe
from urllib.request import FancyURLopener
from urllib.request import urlopen
import urllib.request
import xml.etree.ElementTree as ET
import numpy as np
import datetime
import ssl
import warnings
from datetime import datetime, timedelta

# %%
pd.options.display.max_rows = None
pd.options.display.float_format = '{:.2f}'.format

warnings.filterwarnings("ignore", category=FutureWarning, message="Inferring datetime64.*")

# %% [markdown]
# ## 2.- LECTURA DE DATAFRAMES

# %% [markdown]
# ### 2.1 LECTURA "EMPLEADOS"

# %%
url = 'http://asp.maximise.cl/query.ashx?alias=gsea&user=excel_bd&password=excel_bd&filename=Gestion%5C%5CListo%20de%20Empleados%20Clasificados.txt'

# Descargar el archivo XML desde la URL
with urllib.request.urlopen(url) as response:
    xml_data = response.read()

# Parsear el archivo XML
root = ET.fromstring(xml_data)

# Crear una lista de diccionarios con los datos
data = []
for child in root:
    row = {}
    for subchild in child:
        row[subchild.tag] = subchild.text
    data.append(row)

# Convertir la lista de diccionarios en un dataframe de Pandas
df_empleados = pd.DataFrame(data)

# %%
# Imprimir el dataframe
df_empleados.to_csv('archivos_respaldo_dash2/df_empleados.csv', index = False)
df_empleados.sample(5)
# Out:
#     IDEMPLEADO         RUT             Nombre apellidopaterno apellidomaterno  \
# 20     8282106  24769866-3   Francisco Javier         Aguilar          Garcia
# 241   14428523  14428523-9       Ruth Carolyn          Leyton         Arevalo
# 691   19343402  19343402-9  Gerald Cristopher        Martinez        Carrasco
# 403   16797382  16797382-5  Guillermo  Isaias           Cocio           Chapa
# 65    10309353  10309353-8     Pablo Dionicio         Escobar          Epulef
#
#     idtipoempleado
# 20              GE
# 241             IN
# 691             GE
# 403             EX
# 65              GE

# %% [markdown]
# ### 2.2 LECTURA "MAESTRO DE PRODUCTOS"

# %%
import urllib.request

url = 'https://asp.maximise.cl/query.ashx?alias=gsea&user=excel_bd&password=excel_bd&filename=Gestion\Maestro%20de%20Productos.txt'

# Disable SSL certificate verification (not recommended for production)
with urllib.request.urlopen(url, context=ssl._create_unverified_context()) as response:
    xml_data = response.read()

# Parsear el archivo XML
root = ET.fromstring(xml_data)

# Crear una lista de diccionarios con los datos
data = []
for child in root:
    row = {}
    for subchild in child:
        row[subchild.tag] = subchild.text
    data.append(row)

# Convertir la lista de diccionarios en un dataframe de Pandas
df_productos = pd.DataFrame(data)

df_productos.sample(10)
# Out:
#      Part_Number                                        Descripcion Categoria  \
# 1348   P07121576  Tarjeta interfaz operador EST 3 4X-12SR interf...       P07
# 2526   S10272833  Destrabador Largo Electromagnetico con placa p...       S10
# 2891   T14372323                    Abrazadera OMEGA Metalica Ø16mm       T14
# 2145   P08202832                                     Tee 2 1/2" NPT       P08
# 604    H21580495                            Taladro percusion 13 mm       H21
# 1095   I16431551                              Relay (rele) 220 Volt       I16
# 2448   S10252412          Lector Proximidad Rosslare AY-K12 125 kHz       S10
# 355    C05631417  Telefono SIP X3SP estandar 2 ctas POE pantalla...       C05
# 773    H21582721          Taladro Rotomartillo Bosch GBH-2-24D 820W       H21
# 2713   S12332309  Kit BFT para articular barreras rectangulares ...       S12
#
#      Familia Costo_Promedio Ultimo_x0020_Costo        Fecha_Ultima_Compra
# 1348      12            NaN                NaN                        NaN
# 2526      27          13823            13184.5  2023-06-06T00:00:00-04:00
# 2891      37             40                 40  2019-11-11T00:00:00-03:00
# 2145      20           1800                NaN  2017-03-27T00:00:00-03:00
# 604       58          54613           54613.44  2022-05-09T00:00:00-03:00
# 1095      43           9613               9613  2020-08-31T00:00:00-03:00
# 2448      25          27580              27580  2023-03-30T00:00:00-03:00
# 355       63          21669         21668.9202  2017-03-24T00:00:00-03:00
# 773       58         110840             110840  2023-06-07T00:00:00-04:00
# 2713      33         232148             232148  2021-03-08T00:00:00-03:00

# %% [markdown]
# ### 2.3 LECTURA "LIBRO MAYOR BASE"

# %%
archivo_csv = 'archivos_respaldo/df_libro_mayor5_base2.csv'  # Reemplaza 'ruta_del_archivo.csv' con la ubicación real de tu archivo CSV
# Leer el archivo CSV y crear un DataFrame
df_libro_mayor_base = pd.read_csv(archivo_csv)
print("DIMENSIONES DE df_libro_mayor_base:", df_libro_mayor_base.shape)
df_libro_mayor_base.sample(10)
# Out:
# DIMENSIONES DE df_libro_mayor_base: (340, 5)
#     CODIGO_PROYECTO            TIPO_CUENTA  TOTAL_LB  \
# 276          P-1683  3. COSTO MANO DE OBRA         0
# 190          P-1626             1. INGRESO         0
# 111          P-1705             1. INGRESO         0
# 301          P-1701   4. COSTO SUPERVISIÓN         0
# 38           P-1675    2. COSTO MATERIALES         0
# 152          P-1723    2. COSTO MATERIALES         0
# 243          P-1666             1. INGRESO         0
# 201          P-1639   4. COSTO SUPERVISIÓN         0
# 95           P-1699    2. COSTO MATERIALES         0
# 183          P-1611   4. COSTO SUPERVISIÓN         0
#
#                    NOMBRE_OBRA  \
# 276                  CD BP-A05
# 190            CLINICA BIO BIO
# 111               LOS CLARINES
# 301           EDIFICIO ZENTENO
# 38                   PALENA II
# 152  VILLA PANAMERICANA LOTE C
# 243               CD AXIONLONG
# 201                  LYON 2546
# 95   VILLA PANAMERICANA LOTE B
# 183       EDIFICIO PLAZA EGAÑA
#
#                                         NOMBRE_CLIENTE
# 276                                          EBCO S.A.
# 190                              CONSTRUCTORA LYD S.A.
# 111                           CONSTRUCTORA INARCO S.A.
# 301                           CONSTRUCTORA GREVIA SPA.
# 38                               CONSTRUCTORA MYA SPA.
# 152                    CONSTRUCTORA MENA Y OVALLE S.A.
# 243                                          EBCO S.A.
# 201  MOLLER Y PEREZ - COTAPOS CONSTRUCCIONES INDUST...
# 95                       EMPRESA CONSTRUCTORA DLP S.A.
# 183                                          EBCO S.A.

# %% [markdown]
# ### 2.4 LECTURA "LIBRO MAYOR"

# %%
archivo_csv = 'archivos_respaldo/df_libro_mayor2.csv'  # Reemplaza 'ruta_del_archivo.csv' con la ubicación real de tu archivo CSV
# Leer el archivo CSV y crear un DataFrame
df_libro_mayor2 = pd.read_csv(archivo_csv)
print("DIMENSIONES DE df_libro_mayor:", df_libro_mayor2.shape)
df_libro_mayor2.sample(10)
# Out:
# DIMENSIONES DE df_libro_mayor: (24899, 18)
#        Unnamed: 0 Codigo_proyecto Cta_Contable   Año Mes  \
# 7808      7808.00          P-1707  4150002-000  2023   5
# 13680     5380.00          P-1694  4101010-000  2023   5
# 5580      5580.00          P-1716  4101010-000  2023   5
# 15579     7279.00          P-1699  4150002-000  2023   3
# 14740     6440.00          P-1707  4101010-000  2023   6
# 21647     5047.00          P-1725  4101010-000  2023   5
# 11900     3600.00          P-1723  4101010-000  2023   4
# 20326     3726.00          P-1688  4101010-000  2023   4
# 6142      6142.00          P-1712  4101010-000  2023   6
# 10573     2273.00          P-1696  4101010-000  2023   2
#
#                            Fecha Tipo_Comp Num_Comp  \
# 7808   2023-05-31T00:00:00-04:00       AJC     1844
# 13680  2023-05-11T00:00:00-03:00       CIN      550
# 5580   2023-05-17T00:00:00-04:00       CIN      946
# 15579  2023-03-31T00:00:00-03:00       AJC     1694
# 14740  2023-06-08T00:00:00-04:00       CIN      268
# 21647  2023-05-05T00:00:00-03:00       CIN      124
# 11900  2023-04-04T00:00:00-03:00       CIN       62
# 20326  2023-04-05T00:00:00-03:00       CIN      144
# 6142   2023-06-05T00:00:00-04:00       CIN       87
# 10573  2023-02-16T00:00:00-03:00       CIN      433
#
#                                                    Glosa Primer_Analisis  \
# 7808                    REMUNERACIONES DIRECTAS PROYECTO          P-1707
# 13680           Carga 75 ohm terminal F con bloqueo de D          P-1694
# 5580            Conduit galvanizado EMT 20 x3000mm (1/2"          P-1716
# 15579                   REMUNERACIONES DIRECTAS PROYECTO          P-1699
# 14740  Kit DSC PRO128 (central/teclado/fuente poder/g...          P-1707
# 21647                    Cinta Aisladora 3M Temflex 1500          P-1725
# 11900                    Roseta FTTH Plana c/guia SC/APC          P-1723
# 20326           Conector de poder 3.5mm macho (para cama          P-1688
# 6142                             Amarras plasticas 300mm          P-1712
# 10573                                Broca HSS metal 6mm          P-1696
#
#       Referencia  Debito Credito Num_Referencia Debito_2 Credito_2    TOTAL  \
# 7808    18606841  886261       0            NaN   886261         0  -886261
# 13680  C06112034   28204       0          51078    28204         0   -28204
# 5580   T14370122  102000       0          51236   102000         0  -102000
# 15579   21055081  197285       0            NaN   197285         0  -197285
# 14740  S11282615  188056       0          51657   188056         0  -188056
# 21647  I16430107    2396       0          50892     2396         0    -2396
# 11900  C08712545   50323       0          50188    50323         0   -50323
# 20326  S09240029    1024       0          50238     1024         0    -1024
# 6142   I16431048    1700       0          51515     1700         0    -1700
# 10573  I17442579    5305       0          49471     5305         0    -5305
#
#               Tipo_cuenta
# 7808   COSTO MANO DE OBRA
# 13680    COSTO MATERIALES
# 5580     COSTO MATERIALES
# 15579  COSTO MANO DE OBRA
# 14740    COSTO MATERIALES
# 21647    COSTO MATERIALES
# 11900    COSTO MATERIALES
# 20326    COSTO MATERIALES
# 6142     COSTO MATERIALES
# 10573    COSTO MATERIALES

# %% [markdown]
# ## 3.- TRATAMIENTO DE DATAFRAMES

# %% [markdown]
# ### 3.1- TRATAMIENTO 1 - EMPLEADOS

# %%
# Función para categorizar la columna 'idtipoempleado'

def categorizar_pl(idtipoempleado):
    if idtipoempleado =="GC" or idtipoempleado == "SC" or idtipoempleado == "TC":
        return 'CCDD'
    elif idtipoempleado =="GP" or idtipoempleado == "SP" or idtipoempleado == "TP":
        return 'PIPING'
    else:
        return 'OTRA'

# Crear la nueva columna 'idtipoempleado' aplicando la función
df_empleados['PL'] = df_empleados['idtipoempleado'].apply(categorizar_pl)
df_empleados.sample(10)
# Out:
#     IDEMPLEADO         RUT             Nombre apellidopaterno apellidomaterno  \
# 125   12502891  12502891-8       Juan Agustin        Troncoso           Lagos
# 156   13062659  13062659-9        German Hugo          Torres         Becerra
# 768   20497896  20497896-4    Bryan Alexander         Vasquez         Riveros
# 707   19561822  19561822-4   Martin Alejandro       Contreras            Cruz
# 796   21198760  21198760-K       Gerald Ariel         Escobar         Escobar
# 316   15887129  15887129-7    Yerko Alejandro        Gonzalez         Vergara
# 687   19283436  19283436-8       Juan Eduardo           Lagos           Muñoz
# 8      7312675   7312675-4     Demetrio Roque          Agloni         Del Amo
# 346   16241233  16241233-7      Carlos Andres     Covarrubias          Molina
# 675   19183409  19183409-7  Alejandro Antonio            Pino         Pereira
#
#     idtipoempleado    PL
# 125             GE  OTRA
# 156             EX  OTRA
# 768             TT  OTRA
# 707             PI  OTRA
# 796             EX  OTRA
# 316             PI  OTRA
# 687             CD  OTRA
# 8               AF  OTRA
# 346             GE  OTRA
# 675             GE  OTRA

# %%
# Visualización del dataframe formato PIVOT:
df_empleados_piv = pd.pivot_table(df_empleados, values=['IDEMPLEADO'], index=['PL'], aggfunc= 'count', fill_value=0)
df_empleados_piv
# Out:
#         IDEMPLEADO
# PL
# OTRA           896
# PIPING           3

# %% [markdown]
# ### 3.1- TRATAMIENTO 2 - LIBRO MAYOR

# %%
df_libro_mayor2.sample(5)
# Out:
#        Unnamed: 0 Codigo_proyecto Cta_Contable   Año Mes  \
# 444        444.00          P-1713  3101030-000  2023   5
# 5420      5420.00          P-1704  4101010-000  2023   5
# 21929     5329.00          P-1707  4101010-000  2023   5
# 15118     6818.00          P-1690  4101010-000  2023   6
# 3650      3650.00          P-1721  4101010-000  2023   4
#
#                            Fecha Tipo_Comp Num_Comp  \
# 444    2023-05-02T00:00:00-03:00       CVT        4
# 5420   2023-05-12T00:00:00-03:00       CIN      596
# 21929  2023-05-10T00:00:00-03:00       CIN      500
# 15118  2023-06-19T00:00:00-04:00       CIN      742
# 3650   2023-04-04T00:00:00-03:00       CIN       81
#
#                                           Glosa Primer_Analisis  Referencia  \
# 444                               EP DR 51-54-2          P-1713  96568180-9
# 5420        Tee Mecanica 4" x 2" ranurada A-536          P-1704   P08202341
# 21929  Lector Standalone antivandalico Prox y C          P-1707   S10253109
# 15118  Camara domo Hikvision DS-2CE16C0T-IRF(2.          P-1690   S09222547
# 3650                           Bateria 12V 7amp          P-1721   T14390028
#
#        Debito  Credito Num_Referencia Debito_2 Credito_2    TOTAL  \
# 444         0  3617655          13718        0   3617655  3617655
# 5420   215644        0          51126   215644         0  -215644
# 21929  221984        0          51023   221984         0  -221984
# 15118   35820        0          51885    35820         0   -35820
# 3650    46096        0          50207    46096         0   -46096
#
#             Tipo_cuenta
# 444             INGRESO
# 5420   COSTO MATERIALES
# 21929  COSTO MATERIALES
# 15118  COSTO MATERIALES
# 3650   COSTO MATERIALES

# %%
# Función para categorizar la columna 'PRACTICA'

def categorizar_pl(referencia):
    if referencia.startswith("C02") or referencia.startswith("C03") or referencia.startswith("C05") or referencia.startswith("C06") or referencia.startswith("C08"):
        return 'TELECOMUNICACIONES'
    elif referencia.startswith("C04") or referencia.startswith("C07") or referencia.startswith("C05") or referencia.startswith("I16") or referencia.startswith("O1950") or referencia.startswith("P07") or referencia.startswith("S09") or referencia.startswith("S10") or referencia.startswith("S10") or referencia.startswith("S11") or referencia.startswith("S12") or referencia.startswith("S13") or referencia.startswith("T14"):
        return 'CCDD'
    elif referencia.startswith("I15") or referencia.startswith("O1951") or referencia.startswith("C05") or referencia.startswith("C06") or referencia.startswith("P08"):
        return 'PIPING'
    else:
        return 'OTRA'

# Crear la nueva columna 'idtipoempleado' aplicando la función
df_libro_mayor2['PRACTICA'] = df_libro_mayor2['Referencia'].apply(categorizar_pl)
df_libro_mayor2.sample(10)
# Out:
#        Unnamed: 0 Codigo_proyecto Cta_Contable   Año Mes  \
# 1803      1803.00          P-1684  4101010-000  2023   2
# 17958     1358.00          P-1693  4101010-000  2023   1
# 15702     7402.00          P-1725  4150002-000  2023   3
# 571        571.00          P-1712  3101030-000  2023   5
# 14479     6179.00          P-1727  4101010-000  2023   6
# 7380      7380.00          P-1680  4150002-000  2023   3
# 20564     3964.00          P-1709  4101010-000  2023   4
# 13277     4977.00          P-1706  4101010-000  2023   5
# 19631     3031.00          P-1713  4101010-000  2023   3
# 16516     8216.00       P-OFICINA  4150002-003  2023   4
#
#                            Fecha Tipo_Comp Num_Comp  \
# 1803   2023-02-01T00:00:00-03:00       CIN       20
# 17958  2023-01-19T00:00:00-03:00       CIN      740
# 15702  2023-03-31T00:00:00-03:00       AJC     1694
# 571    2023-05-31T00:00:00-04:00       AJC     1823
# 14479  2023-06-05T00:00:00-04:00       CIN      104
# 7380   2023-03-31T00:00:00-03:00       AJC     1694
# 20564  2023-04-12T00:00:00-03:00       AJC     1434
# 13277  2023-05-04T00:00:00-03:00       CIN      102
# 19631  2023-03-14T00:00:00-03:00       CIN      428
# 16516  2023-04-30T00:00:00-03:00       AJC     1681
#
#                                                  Glosa Primer_Analisis  \
# 1803                    Magnetico Embutido 1/4" Blanco          P-1684
# 17958                 Union copla 6" ranurada flexible          P-1693
# 15702                 REMUNERACIONES DIRECTAS PROYECTO          P-1725
# 571            VENTAS DE PROYECTO - CD VIÑA OTLET PARK          P-1712
# 14479                                 Sierra Copa 20mm          P-1727
# 7380                  REMUNERACIONES DIRECTAS PROYECTO          P-1680
# 20564                              COSTOS DE PROYECTOS          P-1709
# 13277         Palanca Incendio SIGA-278 direc accion D          P-1706
# 19631                        Tornillo volcanita 6 x 2"          P-1713
# 16516  REMUNERACIONES DIRECTAS PROYECTO POR DISTRIBUIR       P-Oficina
#
#             Referencia  Debito   Credito Num_Referencia Debito_2 Credito_2  \
# 1803         S11290198   37500         0          49238    37500         0
# 17958        P08200320       0     12470          48998        0     12470
# 15702         27111489  176120         0            NaN   176120         0
# 571         76525290-3       0  15000000            NaN        0  15000000
# 14479        I15410225   14906         0          51533    14906         0
# 7380          21591838  501718         0            NaN   501718         0
# 20564  COMPRA ALMUERZO    6039         0            NaN     6039         0
# 13277        P07120834  357315         0          50873   357315         0
# 19631        I17440306    3200         0          49853     3200         0
# 16516         20577191   47270         0            NaN    47270         0
#
#           TOTAL         Tipo_cuenta PRACTICA
# 1803     -37500    COSTO MATERIALES     CCDD
# 17958     12470    COSTO MATERIALES   PIPING
# 15702   -176120  COSTO MANO DE OBRA     OTRA
# 571    15000000             INGRESO     OTRA
# 14479    -14906    COSTO MATERIALES   PIPING
# 7380    -501718  COSTO MANO DE OBRA     OTRA
# 20564     -6039    COSTO MATERIALES     OTRA
# 13277   -357315    COSTO MATERIALES     CCDD
# 19631     -3200    COSTO MATERIALES     OTRA
# 16516    -47270                OTRA     OTRA

# %% [markdown]
# ## AQUI VOY
